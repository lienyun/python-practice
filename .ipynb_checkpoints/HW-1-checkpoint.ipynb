# %%
import pandas as pd
import numpy as np

namelist = ['李孟青','陳雲琪','倪佳霖','楊學恆','郭淑娟','陳佳桓','林郁婷','姜雅惠','林俊榮','徐鴻禮','林國屏','王嘉玲','倪欣怡','林雅雯','王劭靖','吳雅雪','張致航','張嘉妃','傅俊良','林苑添','劉筱芸','林宜其','林苡苓','楊雅皓','盧友紹','徐丹霞','蕭舜穎','楊依婷','陳韋菱','陳家榮','鄭健齊','柳姿蓉','林建倩','林彥勇','楊柏娥','朱瑩珍','吳盛紫','陳昭紫','陳凱琳','林勳亨','陳冠卉','陳麗星','梁光芸','黃品玄','彭文宏','陳筱智','安維倫','宋筠名','陳秀娟','徐志倫']

labels = ['身高','體重','BMI']

df = pd.DataFrame({
    '姓名':namelist,
    '身高':np.random.randint(140,200,size = 50),
    '體重':np.random.randint(40,100,size = 50),
})

for i in df:
  df['BMI'] = df['體重']/((df['身高']*df['身高'])/10000)
print(df)
data.to_excel("學生名單.xlsx", index=False)

#print('記憶體使用狀況',df.memory_usage(deep = True))
# Out:
#      姓名   身高  體重        BMI
# 0   李孟青  185  74  21.621622
# 1   陳雲琪  157  88  35.701245
# 2   倪佳霖  141  56  28.167597
# 3   楊學恆  193  83  22.282477
# 4   郭淑娟  174  67  22.129740
# 5   陳佳桓  155  69  28.720083
# 6   林郁婷  180  68  20.987654
# 7   姜雅惠  175  85  27.755102
# 8   林俊榮  172  92  31.097891
# 9   徐鴻禮  143  45  22.005966
# 10  林國屏  172  74  25.013521
# 11  王嘉玲  153  99  42.291426
# 12  倪欣怡  160  80  31.250000
# 13  林雅雯  187  76  21.733535
# 14  王劭靖  159  63  24.919900
# 15  吳雅雪  195  68  17.882972
# 16  張致航  147  88  40.723773
# 17  張嘉妃  146  85  39.876149
# 18  傅俊良  142  92  45.625868
# 19  林苑添  156  70  28.763971
# 20  劉筱芸  172  74  25.013521
# 21  林宜其  187  99  28.310790
# 22  林苡苓  151  72  31.577562
# 23  楊雅皓  198  91  23.211917
# 24  盧友紹  190  60  16.620499
# 25  徐丹霞  161  71  27.390919
# 26  蕭舜穎  194  62  16.473589
# 27  楊依婷  161  72  27.776706
# 28  陳韋菱  185  42  12.271731
# 29  陳家榮  169  57  19.957284
# 30  鄭健齊  177  64  20.428357
# 31  柳姿蓉  177  81  25.854639
# ...
